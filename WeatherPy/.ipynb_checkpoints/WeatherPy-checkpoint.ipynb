# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 576

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # pprint(city_weather)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | isafjordur
# Processing Record 3 of Set 1 | badger
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | milagros
# Processing Record 6 of Set 1 | sievi
# Processing Record 7 of Set 1 | kill devil hills
# Processing Record 8 of Set 1 | stanley
# Processing Record 9 of Set 1 | yinchuan
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | chonchi
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | nagqu
# Processing Record 14 of Set 1 | kalmunai
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | puerto natales
# Processing Record 18 of Set 1 | siavonga
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | aljezur
# Processing Record 21 of Set 1 | walvis bay
# Processing Record 22 of Set 1 | fort bragg
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | bilibino
# Processing Record 28 of Set 1 | tsiombe
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | puerto deseado
# Processing Record 31 of Set 1 | coquimbo
# Processing Record 32 of Set 1 | malvan
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | udachny
# Processing Record 35 of Set 1 | vorkuta
# Processing Record 36 of Set 1 | vorgashor
# Processing Record 37 of Set 1 | afaahiti
# Processing Record 38 of Set 1 | bel ombre
# Processing Record 39 of Set 1 | vilyuysk
# Processing Record 40 of Set 1 | grytviken
# Processing Record 41 of Set 1 | praia da vitoria
# Processing Record 42 of Set 1 | blackmans bay
# Processing Record 43 of Set 1 | axim
# Processing Record 44 of Set 1 | nova sintra
# Processing Record 45 of Set 1 | kankanhalli
# Processing Record 46 of Set 1 | kavieng
# Processing Record 47 of Set 1 | margaret river
# Processing Record 48 of Set 1 | tolanaro
# Processing Record 49 of Set 1 | kasongo
# Processing Record 50 of Set 1 | roma
# Processing Record 0 of Set 2 | laibin
# Processing Record 1 of Set 2 | constantia
# Processing Record 2 of Set 2 | northam
# Processing Record 3 of Set 2 | thames
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | camiri
# Processing Record 6 of Set 2 | ust-nera
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | magadan
# Processing Record 10 of Set 2 | cabedelo
# Processing Record 11 of Set 2 | atafu village
# Processing Record 12 of Set 2 | sambava
# Processing Record 13 of Set 2 | colonia
# Processing Record 14 of Set 2 | sisimiut
# Processing Record 15 of Set 2 | uturoa
# Processing Record 16 of Set 2 | malone
# Processing Record 17 of Set 2 | crane
# Processing Record 18 of Set 2 | imbituba
# Processing Record 19 of Set 2 | esmeraldas
# Processing Record 20 of Set 2 | port lincoln
# Processing Record 21 of Set 2 | alpine
# Processing Record 22 of Set 2 | keflavik
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | nouadhibou
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | alice springs
# Processing Record 27 of Set 2 | lihue
# Processing Record 28 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 29 of Set 2 | babana
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | papatowai
# Processing Record 32 of Set 2 | flying fish cove
# Processing Record 33 of Set 2 | holualoa
# Processing Record 34 of Set 2 | chifeng
# Processing Record 35 of Set 2 | argo
# Processing Record 36 of Set 2 | waingapu
# Processing Record 37 of Set 2 | yatou
# Processing Record 38 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record
of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | pathein
# Processing Record 24 of Set 4 | al jawf
# Processing Record 25 of Set 4 | itaituba
# Processing Record 26 of Set 4 | barranca
# Processing Record 27 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 4 | carutapera
# Processing Record 29 of Set 4 | kem'
# Processing Record 30 of Set 4 | zacoalco de torres
# Processing Record 31 of Set 4 | kelibia
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | vilyuchinsk
# Processing Record 34 of Set 4 | hard bargain
# Processing Record 35 of Set 4 | nikolayevsk-on-amure
# Processing Record 36 of Set 4 | zhuanghe
# Processing Record 37 of Set 4 | bestobe
# Processing Record 38 of Set 4 | taltal
# Processing Record 39 of Set 4 | peace river
# Processing Record 40 of Set 4 | el tigre
# Processing Record 41 of Set 4 | kourou
# Processing Record 42 of Set 4 | zuunmod
# Processing Record 43 of Set 4 | hawaiian paradise park
# Processing Record 44 of Set 4 | malango
# Processing Record 45 of Set 4 | staroleushkovskaya
# Processing Record 46 of Set 4 | weno
# Processing Record 47 of Set 4 | ust'-talovka
# Processing Record 48 of Set 4 | querqueville
# Processing Record 49 of Set 4 | puerto baquerizo moreno
# Processing Record 0 of Set 5 | talcahuano
# Processing Record 1 of Set 5 | kingsville
# Processing Record 2 of Set 5 | brookings
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | georgetown
# Processing Record 5 of Set 5 | avarua
# Processing Record 6 of Set 5 | smithers
# Processing Record 7 of Set 5 | karratha
# Processing Record 8 of Set 5 | eyl
# Processing Record 9 of Set 5 | al kharijah
# Processing Record 10 of Set 5 | arvika
# Processing Record 11 of Set 5 | conduaga
# Processing Record 12 of Set 5 | guatire
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | marquette
# Processing Record 15 of Set 5 | biltine
# Processing Record 16 of Set 5 | massawa
# Processing Record 17 of Set 5 | lata
# Processing Record 18 of Set 5 | nova vicosa
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | mocorito
# Processing Record 21 of Set 5 | beloyarskiy
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | fale old settlement
# Processing Record 24 of Set 5 | prince rupert
# Processing Record 25 of Set 5 | hirara
# Processing Record 26 of Set 5 | dezhou
# Processing Record 27 of Set 5 | kudahuvadhoo
# Processing Record 28 of Set 5 | maysville
# Processing Record 29 of Set 5 | ceeldheer
# Processing Record 30 of Set 5 | juneau
# Processing Record 31 of Set 5 | dudinka
# Processing Record 32 of Set 5 | salekhard
# Processing Record 33 of Set 5 | andenne
# Processing Record 34 of Set 5 | orapa
# Processing Record 35 of Set 5 | arteche
# Processing Record 36 of Set 5 | maubin
# Processing Record 37 of Set 5 | broome
# Processing Record 38 of Set 5 | envira
# Processing Record 39 of Set 5 | rajanpur
# Processing Record 40 of Set 5 | alexandria
# Processing Record 41 of Set 5 | weihai
# Processing Record 42 of Set 5 | egilsstadir
# Processing Record 43 of Set 5 | hubli
# Processing Record 44 of Set 5 | ancud
# Processing Record 45 of Set 5 | saint-denis
# Processing Record 46 of Set 5 | naze
# Processing Record 47 of Set 5 | daru
# Processing Record 48 of Set 5 | chai badan
# Processing Record 49 of Set 5 | yarmouth
# Processing Record 0 of Set 6 | anibare
# City not found. Skipping...
# Processing Record 1 of Set 6 | sinjai
# Processing Record 2 of Set 6 | sur
# Processing Record 3 of Set 6 | papao
# Processing Record 4 of Set 6 | ndibene dahra
# Processing Record 5 of Set 6 | costa calma
# City not found. Skipping...
# Processing Record 6 of Set 6 | rio grande
# Processing Record 7 of Set 6 | noumea
# Processing Record 8 of Set 6 | khandud
# Processing Record 9 of Set 6 | tazacorte
# Processing Record 10 of Set 6 | dean funes
# Processing Record 11 of Set 6 | armacao de buzios
# Processing Record 12 of Set 6 | yurgamysh
# Processing Record 13 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 14 of Set 6 | cajabamba
# Processing Record 15 of Set 6 | burang
# Processing Record 16 of Set 6 | la gi
# Processing Record 17 of Set 6 | nynashamn
# Processing Record 18 of Set 6 | mejit
# Processing Record 19 of Set 6 | north bend
# Processing Record 20 of Set 6 | reggane
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | casper
# Processing Record 23 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 24 of Set 6 | dzuunmod
# Processing Record 25 of Set 6 | aasiaat
# Processing Record 26 of Set 6 | greenville
# Processing Record 27 of Set 6 | dolbeau-mistassini
# Processing Record 28 of Set 6 | haiku-pauwela
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | meulaboh
# Processing Record 32 of Set 6 | linhares
# Processing Record 33 of Set 6 | dedovichi
# Processing Record 34 of Set 6 | san pedro pochutla
# Processing Record 35 of Set 6 | itamaraca
# Processing Record 36 of Set 6 | kapuskasing
# Processing Record 37 of Set 6 | lae
# Processing Record 38 of Set 6 | najran
# Processing Record 39 of Set 6 | mansa
# Processing Record 40 of Set 6 | port douglas
# Processing Record 41 of Set 6 | del rio
# Processing Record 42 of Set 6 | fannuj
# City not found. Skipping...
# Processing Record 43 of Set 6 | san antonio de pale
# Processing Record 44 of Set 6 | geneina
# Processing Record 45 of Set 6 | dashitou
# Processing Record 46 of Set 6 | challapata
# Processing Record 47 of Set 6 | kipushi
# Processing Record 48 of Set 6 | linden
# Processing Record 49 of Set 6 | lima
# Processing Record 0 of Set 7 | puerto real
# Processing Record 1 of Set 7 | mili
# Processing Record 2 of Set 7 | contai
# Processing Record 3 of Set 7 | lamarque
# Processing Record 4 of Set 7 | ballynahinch
# Processing Record 5 of Set 7 | touros
# Processing Record 6 of Set 7 | khash
# Processing Record 7 of Set 7 | mukalla
# Processing Record 8 of Set 7 | strathalbyn
# Processing Record 9 of Set 7 | at taj
# Processing Record 10 of Set 7 | namibe
# Processing Record 32 of Set 8 | kirovsk
# Processing Record 33 of Set 8 | leava
# Processing Record 34 of Set 8 | sant antoni de portmany
# Processing Record 35 of Set 8 | piti village
# Processing Record 36 of Set 8 | howrah
# Processing Record 37 of Set 8 | selkirk
# Processing Record 38 of Set 8 | manatutu
# City not found. Skipping...
# Processing Record 39 of Set 8 | saipan
# Processing Record 40 of Set 8 | santa rosa misiones
# Processing Record 41 of Set 8 | nanzhou
# Processing Record 42 of Set 8 | mossendjo
# Processing Record 43 of Set 8 | alotau
# Processing Record 44 of Set 8 | santa maria
# Processing Record 45 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 46 of Set 8 | priargunsk
# Processing Record 47 of Set 8 | dauphin
# Processing Record 48 of Set 8 | saint george's
# Processing Record 49 of Set 8 | itoman
# Processing Record 0 of Set 9 | saint-paul
# Processing Record 1 of Set 9 | remire-montjoly
# Processing Record 2 of Set 9 | bodo
# Processing Record 3 of Set 9 | huadian
# Processing Record 4 of Set 9 | tukrah
# Processing Record 5 of Set 9 | nuku'alofa
# Processing Record 6 of Set 9 | salinopolis
# Processing Record 7 of Set 9 | nayoro
# Processing Record 8 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 9 of Set 9 | prado
# Processing Record 10 of Set 9 | barcelos
# Processing Record 11 of Set 9 | saint-peray
# Processing Record 12 of Set 9 | kaya
# Processing Record 13 of Set 9 | okha
# Processing Record 14 of Set 9 | thinadhoo
# Processing Record 15 of Set 9 | taulaga
# Processing Record 16 of Set 9 | parkersburg
# Processing Record 17 of Set 9 | orangeburg
# Processing Record 18 of Set 9 | nizamabad
# Processing Record 19 of Set 9 | arboletes
# Processing Record 20 of Set 9 | sassnitz
# Processing Record 21 of Set 9 | princeton
# Processing Record 22 of Set 9 | happy valley-goose bay
# Processing Record 23 of Set 9 | novozavedennoye
# Processing Record 24 of Set 9 | medicine hat
# Processing Record 25 of Set 9 | yemetsk
# Processing Record 26 of Set 9 | spirovo
# Processing Record 27 of Set 9 | buka
# Processing Record 28 of Set 9 | ciudad tula
# Processing Record 29 of Set 9 | siwa oasis
# Processing Record 30 of Set 9 | bloemendaal
# Processing Record 31 of Set 9 | sechura
# Processing Record 32 of Set 9 | sanctuary point
# Processing Record 33 of Set 9 | tadine
# Processing Record 34 of Set 9 | ha'il
# Processing Record 35 of Set 9 | aswan
# Processing Record 36 of Set 9 | santa quiteria
# Processing Record 37 of Set 9 | bulungu
# Processing Record 38 of Set 9 | new norfolk
# Processing Record 39 of Set 9 | maracaju
# Processing Record 40 of Set 9 | flin flon
# Processing Record 41 of Set 9 | le port
# Processing Record 42 of Set 9 | tenenkou
# Processing Record 43 of Set 9 | nadi
# Processing Record 44 of Set 9 | wellington
# Processing Record 45 of Set 9 | pagar alam
# Processing Record 46 of Set 9 | bugiri
# Processing Record 47 of Set 9 | nema
# Processing Record 48 of Set 9 | ndende
# Processing Record 49 of Set 9 | bubaque
# Processing Record 0 of Set 10 | nar'yan-mar
# Processing Record 1 of Set 10 | volnovakha
# Processing Record 2 of Set 10 | lahore
# Processing Record 3 of Set 10 | qianzhou
# Processing Record 4 of Set 10 | cadale
# Processing Record 5 of Set 10 | smara
# Processing Record 6 of Set 10 | gadzhiyevo
# Processing Record 7 of Set 10 | masumbwe
# Processing Record 8 of Set 10 | la maddalena
# Processing Record 9 of Set 10 | vadso
# Processing Record 10 of Set 10 | tarrafal
# Processing Record 11 of Set 10 | hammerfest
# Processing Record 12 of Set 10 | pestovo
# Processing Record 13 of Set 10 | el granada
# Processing Record 14 of Set 10 | gueret
# Processing Record 15 of Set 10 | aykhal
# Processing Record 16 of Set 10 | maqat
# Processing Record 17 of Set 10 | kuala belait
# Processing Record 18 of Set 10 | manghit
# Processing Record 19 of Set 10 | aflou
# Processing Record 20 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 21 of Set 10 | moanda
# Processing Record 22 of Set 10 | micheweni
# Processing Record 23 of Set 10 | redding
# Processing Record 24 of Set 10 | wad az zaki
# Processing Record 25 of Set 10 | igarka
# Processing Record 26 of Set 10 | tervel
# Processing Record 27 of Set 10 | ostersund
# Processing Record 28 of Set 10 | as sulayyil
# Processing Record 29 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 30 of Set 10 | gwanda
# Processing Record 31 of Set 10 | kamloops
# Processing Record 32 of Set 10 | mount isa
# Processing Record 33 of Set 10 | pierre
# Processing Record 34 of Set 10 | pandan
# Processing Record 35 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 10 | arish
# Processing Record 37 of Set 10 | bukoba
# Processing Record 38 of Set 10 | makoua
# Processing Record 39 of Set 10 | freeport
# Processing Record 40 of Set 10 | kailua-kona
# Processing Record 41 of Set 10 | afif
# Processing Record 42 of Set 10 | zhaotong
# Processing Record 43 of Set 10 | calbuco
# Processing Record 44 of Set 10 | krasnoarmeyskoye
# Processing Record 45 of Set 10 | sabang
# Processing Record 46 of Set 10 | karystos
# Processing Record 47 of Set 10 | tionk essil
# Processing Record 48 of Set 10 | rupert
# Processing Record 49 of Set 10 | san jose del guaviare
# Processing Record 0 of Set 11 | bako
# Processing Record 1 of Set 11 | puerto cabello
# Processing Record 2 of Set 11 | akjoujt
# Processing Record 3 of Set 11 | hungnam
# Processing Record 4 of Set 11 | nanao
# Processing Record 5 of Set 11 | karaj
# Processing Record 6 of Set 11 | camocim
# Processing Record 7 of Set 11 | howard springs
# Processing Record 8 of Set 11 | big spring
# Processing Record 9 of Set 11 | fortuna
# Processing Record 10 of Set 11 | severo-yeniseyskiy
# Processing Record 11 of Set 11 | taoudenni
# Processing Record 12 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 13 of Set 11 | sandnessjoen
# Processing Record 14 of Set 11 | santanyi
# Processing Record 15 of Set 11 | rio pardo de minas
# Processing Record 16 of Set 11 | penha
# Processing Record 17 of Set 11 | lorengau
# Processing Record 18 of Set 11 | bhamo
# Processing Record 19 of Set 11 | shanting
# Processing Record 20 of Set 11 | canutama
# Processing Record 21 of Set 11 | rukungiri
# Processing Record 22 of Set 11 | lazaro cardenas
# Processing Record 23 of Set 11 | yanbu
# Processing Record 24 of Set 11 | basco
# Processing Record 25 of Set 11 | cidreira
# Processing Record 26 of Set 11 | amnat charoen
# Processing Record 27 of Set 11 | livani
# Processing Record 28 of Set 11 | skeldon
# Processing Record 29 of Set 11 | ciudad constitucion
# Processing Record 30 of Set 11 | villa gonzalez ortega
# Processing Record 31 of Set 11 | alo
# Processing Record 32 of Set 11 | victorica
# Processing Record 33 of Set 11 | le mars
# Processing Record 34 of Set 11 | bulayevo
# Processing Record 35 of Set 11 | sanchor
# Processing Record 36 of Set 11 | murashi
# Processing Record 37 of Set 11 | airway heights
# Processing Record 38 of Set 11 | anloga
# Processing Record 39 of Set 11 | jurmala
# Processing Record 40 of Set 11 | sao pedro do sul
# Processing Record 41 of Set 11 | belyy yar
# Processing Record 42 of Set 11 | benguela
# Processing Record 43 of Set 11 | bam
# Processing Record 44 of Set 11 | usinsk
# Processing Record 45 of Set 11 | dickinson
# Processing Record 46 of Set 11 | strezhevoy
# Processing Record 47 of Set 11 | labrador city
# Processing Record 48 of Set 11 | jawf al maqbabah
# Processing Record 49 of Set 11 | ketchikan
# Processing Record 0 of Set 12 | kiruna
# Processing Record 1 of Set 12 | santo antonio do ica
# Processing Record 2 of Set 12 | brisas de zicatela
# Processing Record 3 of Set 12 | liwale
# Processing Record 4 of Set 12 | aginskoye
# Processing Record 5 of Set 12 | east london
# Processing Record 6 of Set 12 | hadibu
# Processing Record 7 of Set 12 | nampula
# Processing Record 8 of Set 12 | novyy urengoy
# Processing Record 9 of Set 12 | krasnyy chikoy
# Processing Record 10 of Set 12 | sabha
# Processing Record 11 of Set 12 | sirjan
# Processing Record 12 of Set 12 | parabel'
# Processing Record 13 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 14 of Set 12 | upper grand lagoon
# Processing Record 15 of Set 12 | cooper's town
# Processing Record 16 of Set 12 | la passe
# Processing Record 17 of Set 12 | abepura
# Processing Record 18 of Set 12 | baardheere
# Processing Record 19 of Set 12 | xilin hot
# Processing Record 20 of Set 12 | mawlaik
# Processing Record 21 of Set 12 | borzya
# Processing Record 22 of Set 12 | ciurea
# Processing Record 23 of Set 12 | anderson
# Processing Record 24 of Set 12 | ponta delgada
# Processing Record 25 of Set 12 | hasaki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame (city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()

# TEMP IS TOO HIGH
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676  -12.3116    286.81        76
# 1                   isafjordur  66.0755  -23.1240    273.14        98
# 2                       badger  64.8000 -147.5333    261.68        86
# 3                     waitangi -43.9535 -176.5597    286.94        75
# 4                     milagros  12.2181  123.5095    299.39        83
#
#    Cloudiness  Wind Speed Country        Date
# 0           8        6.96      SH  1730320486
# 1          98        1.84      IS  1730320488
# 2          20        1.54      US  1730320252
# 3          20        2.24      NZ  1730320491
# 4         100        4.08      PH  1730320493

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116    286.81        76
# 1                         isafjordur  66.0755  -23.1240    273.14        98
# 2                             badger  64.8000 -147.5333    261.68        86
# 3                           waitangi -43.9535 -176.5597    286.94        75
# 4                           milagros  12.2181  123.5095    299.39        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 8        6.96      SH  1730320486
# 1                98        1.84      IS  1730320488
# 2                20        1.54      US  1730320252
# 3                20        2.24      NZ  1730320491
# 4               100        4.08      PH  1730320493

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df['Lat']
temperature = city_data_df['Max Temp']
plt.scatter(latitude, temperature, marker="o", facecolors="red", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2024-10-29)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']
plt.scatter(latitude, humidity, marker="o", facecolors="CadetBlue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2024-10-30)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']
plt.scatter(latitude, cloudiness, marker="o", facecolors="DarkGray", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2024-10-30)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed

latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']
plt.scatter(latitude, wind_speed, marker="o", facecolors="GhostWhite", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2024-10-30)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# Xpert Learning Assistant showed me how to create/define a function (first line only)
def create_linear_regression_plot(x_values, y_values):

    #perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    #calculate regression values
    regress_values = x_values * slope + intercept

    #create the line regression string
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    #create a scatter plot
    plt.scatter(x_values, y_values)

    #plot the regression line
    plt.plot(x_values, regress_values, "r-")

    # format annotation for the line equation
    plt.annotate(line_eq, (x_values.mean(), y_values.mean()), fontsize=15, color="red")

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              isafjordur  66.0755  -23.1240    273.14        98          98
# 2                  badger  64.8000 -147.5333    261.68        86          20
# 4                milagros  12.2181  123.5095    299.39        83         100
# 5                   sievi  63.9000   24.5000    273.53        60          16
# 6        kill devil hills  36.0307  -75.6760    297.16        67          75
#
#          Wind Speed Country        Date
# City_ID
# 1              1.84      IS  1730320488
# 2              1.54      US  1730320252
# 4              4.08      PH  1730320493
# 5              3.15      FI  1730320494
# 6              2.06      US  1730320496

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116    286.81        76
# 3                           waitangi -43.9535 -176.5597    286.94        75
# 9                          adamstown -25.0660 -130.1015    293.93        78
# 10                           chonchi -42.6128  -73.8092    289.88        61
# 11                      puerto ayora  -0.7393  -90.3518    295.68        89
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 8        6.96      SH  1730320486
# 3                20        2.24      NZ  1730320491
# 9                99       10.64      PN  1730320500
# 10               18        0.07      CL  1730320502
# 11               21        3.58      EC  1730320503

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plt.title("Northern Hemisphere: Latitude vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

create_linear_regression_plot(x_values, y_values)

# The r^2-value is: 0.3940754297489331

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plt.title("Southern Hemisphere: Latitude vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

create_linear_regression_plot(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plt.title("Northern Hemisphere: Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

create_linear_regression_plot(x_values, y_values)

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plt.title("Southern Hemisphere: Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

create_linear_regression_plot(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plt.title("Northern Hemisphere: Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

create_linear_regression_plot(x_values, y_values)

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plt.title("Southern Hemisphere: Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

create_linear_regression_plot(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plt.title("Northern Hemisphere: Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

create_linear_regression_plot(x_values, y_values)

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plt.title("Southern Hemisphere: Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

create_linear_regression_plot(x_values, y_values)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
